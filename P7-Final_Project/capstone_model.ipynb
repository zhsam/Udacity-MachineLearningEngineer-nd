# %% [markdown]
# # Udacity 算法工程师毕业项目

# %% [markdown]
# ### 导入需要的库

# %%
import glob
import pandas as pd
import numpy as np
from IPython.display import Image
import random

# %% [markdown]
# # 数据预处理

# %% [markdown]
# ### 数据探索

# %%
# get test set data route
train_route = glob.glob("./dogs-vs-cats-redux-kernels-edition/train/*")
test_route = glob.glob("./dogs-vs-cats-redux-kernels-edition/test/*")

print('no. of train set: {}'.format(len(train_route)))
print('no. of test set: {}'.format(len(test_route)))
# Out:
# no. of train set: 25000
# no. of test set: 12500

# %% [markdown]
# ### 可视化探索

# %%
random.seed(120)

def getRandomNum(maxNum):
    rand_num = random.randint(0, maxNum)
    print(rand_num)
    return rand_num

# %%
rand_num = getRandomNum(24999)
Image(filename=train_route[rand_num])
# Out:
# 16873

# %%
rand_num = getRandomNum(24999)
Image(filename=train_route[rand_num])
# Out:
# 2989

# %%
rand_num = getRandomNum(24999)
Image(filename=train_route[rand_num])
# Out:
# 11027

# %%
rand_num = getRandomNum(24999)
Image(filename=train_route[rand_num])
# Out:
# 8113

# %%
rand_num = getRandomNum(24999)
Image(filename=train_route[rand_num])
# Out:
# 15294

# %%
rand_num = getRandomNum(12499)
Image(filename=test_route[rand_num]) # random check
# Out:
# 9719

# %%
rand_num = getRandomNum(12499)
Image(filename=test_route[rand_num])
# Out:
# 10895

# %%
rand_num = getRandomNum(12499)
Image(filename=test_route[rand_num])
# Out:
# 8226

# %%
rand_num = 46
Image(filename=test_route[rand_num])
# Image(filename=train_route[rand_num])

# %% [markdown]
# 数据探索发现的问题：
# - 图片大小格式不一
# - 有些图片包含人类(train_8113, train_15294, test_10895)
# - 有些有多个动物(train_2989, train_5382, train_10408, train_11027, test_9719, test_8226)
# - 有些图片过小(test_46, test_232, test_419, test_3852, test_8674)
# - 有些图片包含太多白边内容(test_1605)
# - 有些图片肉眼也很难被识别为狗 (test_126)
# - 有些图片为素描、卡通 (test_200, test_1267, test_2140)

# %% [markdown]
# ### 数据增强
# - [ ] 旋转
# - [ ] 水平/垂直翻转
# - [ ] 平移
# - [ ] 随机裁剪
