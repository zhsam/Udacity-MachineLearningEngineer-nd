# %% [markdown]
# # Udacity 算法工程师毕业项目

# %% [markdown]
# ### 导入需要的库

# %%
import glob
import pandas as pd
import numpy as np
from IPython.display import Image

# %% [markdown]
# # 数据预处理

# %% [markdown]
# ### 数据探索

# %%
# get test set data route
test_set_route = glob.glob("./dogs-vs-cats-redux-kernels-edition/test/*")
train_set_route = glob.glob("./dogs-vs-cats-redux-kernels-edition/train/*")

print('no. of test set: {}'.format(len(test_set_route)))
print('no. of test set: {}'.format(len(train_set_route)))
# Out:
# no. of test set: 12500
# no. of test set: 25000

# %% [markdown]
# ### 可视化探索

# %%
# Out:
# './dogs-vs-cats-redux-kernels-edition/test/9733.jpg'

# %%
Image(filename=test_set_route[2])
